# %%
#http://localhost:8888/notebooks/extract_indd_gemini/2026_apr27_v3.ipynb

Shifts indd to json files using automation of Adobe Indesign. note that the script looks for a list of files

# %%
#http://localhost:8888/notebooks/thecallNER/2026_april8_passinddtodbs.ipynb

Passes the json files from indd into the database

# %%
#http://localhost:8888/notebooks/2026_april20_filelisterforquark_v4.ipynb

prepares a list of the quarkxpress pieces in the form of a javascript function to execute in quarkxpress, which outputs .json files

# %%
#http://localhost:8888/notebooks/thecallNER/2026_april27_passquarktodbs.ipynb

Pass the quarkexpress .json files to the database

# %%
#http://localhost:8888/notebooks/thecallNER/2026_april28_unifyjson_v5.ipynb

Finds cases which do not have a unified json, and transforms either the indd or quark based json.

# %%
#http://localhost:8888/notebooks/thecallNER%2F2026_april27_textfilestojsonb.ipynb

a draft script to pass plain text files into the database (never tested or used)

# %%
# http://localhost:8888/notebooks/thecallNER/2026_april22_extractarticles.ipynb
Pulls nitearticles out of the database

# %%
#note that additional code is in : D:\development\2025_python\2026_Londonproject\notebooks\thecallNER

#2026_april10_NER_revised --> the latest NER function?

# %%
#http://localhost:8888/notebooks/thecallNER/2026_april28_NER_v2.ipynb

performs the NER work on the json_unified
