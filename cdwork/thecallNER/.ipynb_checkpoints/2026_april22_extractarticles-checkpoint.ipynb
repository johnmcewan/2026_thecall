# %%
import psycopg2
from psycopg2 import sql
from psycopg2.extras import execute_values, Json
import logging
import json
import html
import re

# %%
logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')

# %%
DB_PARAMS = {
    'dbname':   'thecall',
    'user':     'postgres',
    'password': 'password',
    'host':     'localhost',
    'port':     '5432'
}

TABLE_SCHEMA = 'articles'
TABLE_NAME   = 'filelist'

# Rows per commit. Reduce if you hit memory limits.
BATCH_SIZE = 500

# %%
# ── Database helpers ──────────────────────────────────────────────────────────

def connect_to_db(params):
    try:
        logging.info("Connecting to PostgreSQL...")
        conn = psycopg2.connect(**params)
        conn.autocommit = False
        logging.info("Connected.")
        return conn
    except psycopg2.Error as e:
        logging.error(f"Connection failed: {e}")
        return None

# %%
# ── Main ──────────────────────────────────────────────────────────────────────

def main():
    conn = connect_to_db(DB_PARAMS)
    if not conn:
        return

    try:


    finally:
        conn.close()
        logging.info("Database connection closed.")
        logging.info(f"Done. Processed: {total_processed}  Errors: {total_errors}")
# Out:
# INFO: Connecting to PostgreSQL...
# INFO: Connected.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 500 rows...
# INFO:   Committed 500 rows.
# INFO: Processing batch of 125 rows...
# INFO:   Committed 125 rows.
# INFO: Database connection closed.
# INFO: Done. Processed: 141125  Errors: 0

# %%
if __name__ == '__main__':
    main()
