# %%
import os
import re
import csv
from datetime import datetime

# %%
source = r"G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5"
destination = r"G:\c_out2"

# %%
def extract_quark_text(file_path):
    """Identifies QuarkXPress 3 files and extracts coherent text blocks."""
    try:
        with open(file_path, 'rb') as f:
            data = f.read()

        print (file_path)
        
        # Check for QuarkXPress 3 signature [cite: 1]
        if not data.startswith(b'MMXPR3'):
            return None

        # Extract printable sequences (MacRoman/ASCII) at least 15 chars long
        # This filters out small binary noise and formatting tags [cite: 10, 17]
        text_blobs = re.findall(b'[\x20-\x7E\xA0-\xFF]{15,}', data)
        
        clean_text = []
        # Keywords to skip (technical metadata in the file) [cite: 8, 10, 161]
        skip_keywords = ['LaserWriter', 'Century-Book', 'QRGB', 'QCMK', 'PnHx', 'TEXT']

        for blob in text_blobs:
            try:
                decoded = blob.decode('mac_roman').strip()
                if not any(k in decoded for k in skip_keywords):
                    # Clean up 'MenÕs' to 'Men's' etc.
                    clean_text.append(decoded)
            except UnicodeDecodeError:
                continue
                
        return "\n\n".join(clean_text)
    except Exception as e:
        return f"Error: {e}"

def run_inventory(source_dir, output_dir):
    """Processes files, creates individual TXTs, and one master CSV."""
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    csv_path = os.path.join(output_dir, "inventory.csv")
    
    with open(csv_path, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['file_name', 'folder', 'date_modified', 'size_kb', 'extracted_text']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        for root, dirs, files in os.walk(source_dir):
            for filename in files:
                file_path = os.path.join(root, filename)
                
                # Get Metadata
                stats = os.stat(file_path)
                dt_mod = datetime.fromtimestamp(stats.st_mtime).strftime('%Y-%m-%d %H:%M:%S')
                size_kb = round(stats.st_size / 1024, 2)
                
                # Extract Text
                content = extract_quark_text(file_path)
                
                if content:
                    # 1. Save individual text file
                    txt_name = f"{filename}.txt"
                    with open(os.path.join(output_dir, txt_name), 'w', encoding='utf-8') as tf:
                        tf.write(content)
                    
                    # 2. Add to CSV
                    writer.writerow({
                        'file_name': filename,
                        'folder': os.path.basename(root),
                        'date_modified': dt_mod,
                        'size_kb': size_kb,
                        'extracted_text': content[:500] + "..." # Truncate for CSV readability
                    })
                    print(f"Processed: {filename}")

# %%
#Set your paths here

run_inventory(source, destination)
# Out:
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\gide-- Let’s Consider
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Spt - Three-peat (Westport )
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Spt - Summer (NFL Coaches)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Spt - Seniors (Southeast)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Spt - Offensive Line (Chiefs)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Spt - New Coach (Central)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Spt - NHL Report (Diversity)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Spt - NHL Report
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Spt - NCAA Raises
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Spt - Monday Niters 9_5
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Spt - Lincoln U. (Hoops)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Spt - Brazil's Supremacy
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Spt - A Rarity (Team Doctor)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Spt - 3-col We've Got The Beef
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Spt - 3-col Knights Looking
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Spt - 3-col Can Westport
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Spt - 1-col Fast Man At Central
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\S-Socially Speaking
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\S-3 col Hilltop Saddle Club
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\S-3 col Annal Black Open
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\S--Cooking
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\S- National Beauty (MUST)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\S- 2 col. At National
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\S - Hometown Hero (MUST)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\S - Club Notes 9_5
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\S - 4-col Celebrating African
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\S - 3-col Ladies Of Link
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\S - 2-col Paying Tribute
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA--Frank Bolden Dead
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News- Blacko (Hearing)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News- Blacko (Black Talk)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News - Study Finds
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News - Special Report #4
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News - Special Report #3
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News - Special Report #2
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News - Special Report  #1
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News - Special - When
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News - Remembering
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News - Radio Tom Joyner
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News - NAACP Oppose
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News - Minority Contractor
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News - Internet
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News - Foster Care
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News - Critics In S. Afric
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News - Bush Will
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News - Blacks Still Out
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News - Blacko (Let's Set)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News - Black US. Capitol
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News - Black America
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News - Amin's Children
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\NNPA News - 1-col Helping A
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N-POWER WHEELCHAIRS AVAILABLE
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N-3-col A Man Of Honor
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N--Urban Leagues 2 pixs
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N- Are You Tired (AD MUST)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - Willie Gary Delivers w_pix
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - Thornberry Boys And Girls
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - Substance Abuse (picnic)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - State Rep. Appointed w_pix
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - Sprint Executive
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - Rev. Cleaver To Speak
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - Midtown Strivers
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - Local Youth Completes
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - Local Woman Receives
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - KCMO NAACP Youth
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - KC. Forums Series
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - Invitation To (MUST)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - Holden Ask For Drought
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - Habitat KC. Seeking (MUST)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - Exercise And Diabetes
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - Doctor's Clinic
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - Center For Construction
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - CALL Editor To Be Honored
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - Black Chamber (MUST)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - Area Groups United
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - Annual African Heritage
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - 3-col Honoring A Humanitar
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - 3-col City Recognizes
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - 3-col African Chamber
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - 3-col Accepting Proclamatio
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - 2-col At Book Signing
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\N - 2-col A Friendly Exchange
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Gide - To Be Equal (Fixing)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Gide - To Be Equal (Archer)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Gide - To Be Equal (Africa)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Gide - Matters of Fact 9_5
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Gide - Ghetto Not Hidden
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Gide - Commentary 9_03
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Gide - Commentary (Worrill)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Gide - Commentary (EJC)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Gide - Comment (Worrill #2)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\George Fraser To Speak
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Ent - The Source
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Ent - Smooth Jazz (MUST)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Ent - Northeast Fall Fest
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Ent - Musicians To Perform
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Ent - City In Motion
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Ent - 3-col Foreign Editions
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\E - MAP Scores (MUST)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\E - Blue River Community
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\E - 1-col New Principal
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C--Witness For Justice
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C--UU To Host
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C--New United Methodist
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C--Centennial Revival
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C--Black Churches
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C -Palestine Baptist (MUST)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C - Willa Player Dies
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C - Violence Leaves Liberia
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C - Selected Pastor Of Month
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C - Religious Leaders
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C - Harlem Mourns
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C - Former Slaves w_pix
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C - Economic Climates
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C - Dorothy Norwood (MUST)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C - Church Women
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C - Church Leaders Find
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C - Blackonomics (Church)
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C - Bennett College w_pix
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C - 3-col Prayer For Repentence
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C - 3-col Pastor of The Month
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C - 3-col Liturgical Praise
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C - 2-col Former Slave
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\C - 1-col A Song of Praise
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\Baptist Convention
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\AP -- St. Louis Schools
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\3 col. car wreck
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\3 col. PRESIDENT OF LINCOLN
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\3 col. PASTORS PREPARING
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\3 col.  Local Host Committee
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\3 col.  DEDICATE NEW FACILOITY
# G:\c_out\Call 09-05\Pages and Pics\Call Editorial-Pics\CALL COPY SEPT. 5\2 COL.  MAJOR EVENTS
