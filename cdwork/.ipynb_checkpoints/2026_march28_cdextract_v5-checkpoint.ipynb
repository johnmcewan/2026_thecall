# %%
import os
import csv
import time
import shutil
import pycdlib

# %%
# ---------- Configuration ----------

SOURCE_DIR = r"G:\thecall\done"
DEST_DIR   = r"e:\c_out"
CSV_PATH   = os.path.join(DEST_DIR, "inventory.csv")
ERROR_LOG  = os.path.join(DEST_DIR, "errors.log")

MAX_FILENAME_LEN = 200  # truncate filenames longer than this (before extension)

# %%
# ---------- Utilities ----------

def safe_path(path):
    """Prepend the Windows long-path prefix so paths > 260 chars work."""
    path = os.path.abspath(path)
    if not path.startswith("\\\\?\\"):
        return "\\\\?\\" + path
    return path


def clean_name(name):
    """Remove characters illegal on Windows and strip ISO version suffix (;1).

    Windows silently rejects directory/file names that end *or begin* with a
    space or period even when using the long-path prefix, so we strip both.
    """
    if ";" in name:
        name = name[:name.rfind(";")]
    name = "".join(c if c not in '<>:"/\\|?*' else "_" for c in name)
    # FIX: strip leading AND trailing spaces/dots (leading spaces cause
    # [Errno 13] Permission denied on Windows with the \\?\ long-path prefix)
    return name.strip(" .")


def truncate_name(name, max_len=MAX_FILENAME_LEN):
    """Truncate a filename while preserving its extension."""
    root, ext = os.path.splitext(name)
    if len(name) <= max_len:
        return name
    return root[: max_len - len(ext)] + ext


def detect_path_type(iso):
    """
    Choose the best path namespace for this ISO:
      'joliet_path' - disc has Joliet extensions (long, Unicode-friendly names)
      'iso_path'    - plain ISO 9660 (8.3 or slightly relaxed names)
    Rock Ridge is skipped; these discs don't have it.
    """
    if iso.joliet_vd is not None:
        return "joliet_path"
    return "iso_path"

# %%
# ---------- Date extraction (Final Refinement) ----------

def _parse_dir_record_date(dt):
    """Parse a DirectoryRecordDate (7-byte format)."""
    try:
        year = getattr(dt, "years_since_1900", None)
        day = getattr(dt, "day_of_month", None)
        if year is None or year == 0 or day is None:
            return ""
        return "{:04d}-{:02d}-{:02d} {:02d}:{:02d}:{:02d}".format(
            year + 1900, dt.month, day, dt.hour, dt.minute, dt.second,
        )
    except: return ""

def _parse_vd_date(dt):
    """Parse a VolumeDescriptorDate (17-byte ASCII format)."""
    if dt is None: return ""
    dstr = getattr(dt, "date_str", b"").decode("ascii", errors="ignore").strip("\x00 ")
    # Check if we have at least YYYYMMDD
    if len(dstr) >= 8 and dstr[:4].isdigit() and dstr[:4] != "0000":
        try:
            return "{}-{}-{} {}:{}:{}".format(
                dstr[0:4], dstr[4:6], dstr[6:8],
                dstr[8:10] or "00", dstr[10:12] or "00", dstr[12:14] or "00"
            )
        except: pass
    return ""

def get_all_dates(iso, iso_file_path, path_type):
    results = {"date_primary": "", "date_secondary": "", "date_volume": "", "date_source": ""}
    
    # 1. File Date (Primary Namespace)
    try:
        rec = iso.get_record(**{path_type: iso_file_path})
        results["date_primary"] = _parse_dir_record_date(rec.date)
    except: pass

    # 2. Volume Dates (The "Disc Date" - checking all 4 standard fields)
    pvd = iso.pvd
    v_cre = _parse_vd_date(getattr(pvd, "cre_date", None))
    v_mod = _parse_vd_date(getattr(pvd, "mod_date", None))
    v_eff = _parse_vd_date(getattr(pvd, "eff_date", None))
    
    # Use the first valid date found for the volume
    results["date_volume"] = v_mod or v_cre or v_eff
    
    # Label the source
    if results["date_primary"]:
        results["date_source"] = path_type
    elif results["date_volume"]:
        results["date_source"] = "volume_descriptor"
        
    return results

def _date_to_epoch(date_str):
    if not date_str: return None
    try: return time.mktime(time.strptime(date_str, "%Y-%m-%d %H:%M:%S"))
    except: return None

def stamp_file_date(out_path, dates):
    """Apply the best available date to the physical file on disk."""
    best = dates["date_primary"] or dates["date_volume"]
    epoch = _date_to_epoch(best)
    if epoch:
        try: os.utime(os.path.abspath(out_path), (epoch, epoch))
        except: pass

def log_error(message):
    with open(ERROR_LOG, "a", encoding="utf-8") as f:
        f.write(f"{time.strftime('%Y-%m-%d %H:%M:%S')} | {message}\n")

# %%
# ---------- Extraction Logic ----------
def extract_iso(iso_path, output_dir, writer, parent_label):

    iso_name = os.path.basename(iso_path)
    iso = pycdlib.PyCdlib()
    try:
        iso.open(iso_path)
    except Exception as e:
        log_error(f"OPEN_FAIL | {iso_path} | {str(e)}")
        # FIX: copy the raw ISO so the file is not silently lost
        dest_copy = os.path.join(output_dir, iso_name)
        try:
            shutil.copy2(iso_path, dest_copy)
            print(f"  [OPEN_FAIL] Copied raw ISO to: {dest_copy}")
        except Exception as copy_err:
            log_error(f"COPY_FAIL | {iso_path} | {str(copy_err)}")
        return

    path_type = detect_path_type(iso)
    print(f"  Path namespace: {path_type}")

    for dir_path, dirs, files in iso.walk(**{path_type: "/"}):
        for file in files:
            iso_file_path = dir_path.rstrip("/") + "/" + file

            try:
                clean_file = truncate_name(clean_name(file))
                rel_dir = dir_path.lstrip("/")
                if rel_dir:
                    rel_dir = os.path.join(*[clean_name(p) for p in rel_dir.split("/") if p])
                else:
                    rel_dir = "."

                out_dir = os.path.join(output_dir, rel_dir)
                out_path = os.path.join(out_dir, clean_file)

                # FIX: [WinError 183] — a prior file was written at a path that
                # is now needed as a directory.  Rename the blocking file so
                # makedirs can proceed, then extract this file normally.
                safe_out_dir = safe_path(out_dir)
                if os.path.isfile(safe_out_dir):
                    renamed = safe_out_dir + "__file_collision"
                    try:
                        os.rename(safe_out_dir, renamed)
                        log_error(
                            f"COLLISION_RENAME | {iso_name} | {iso_file_path} | "
                            f"Renamed blocking file to {renamed}"
                        )
                    except Exception as rename_err:
                        log_error(
                            f"COLLISION_RENAME_FAIL | {iso_name} | {iso_file_path} | "
                            f"{str(rename_err)}"
                        )
                        continue  # skip this file if we can't resolve the collision

                os.makedirs(safe_out_dir, exist_ok=True)
                iso.get_file_from_iso(
                    local_path=safe_path(out_path),
                    **{path_type: iso_file_path},
                )

                dates = get_all_dates(iso, iso_file_path, path_type)
                stamp_file_date(out_path, dates)

                writer.writerow({
                    "iso_file":       iso_name,
                    "parent_folder":  parent_label,
                    "file_name":      clean_file,
                    "original_name":  file,
                    "folder":         rel_dir,
                    "full_path":      out_path,
                    "date_primary":   dates["date_primary"],
                    "date_secondary": dates["date_secondary"],
                    "date_volume":    dates["date_volume"],
                    "date_source":    dates["date_source"],
                    "path_type":      path_type,
                })
            except Exception as e:
                log_error(f"FILE_ERROR | {iso_name} | {iso_file_path} | {str(e)}")

    iso.close()

# %%
def main():
    os.makedirs(DEST_DIR, exist_ok=True)
    
    fieldnames = [
        "iso_file", "parent_folder", "file_name", "original_name", # Added parent_folder
        "folder", "full_path",
        "date_primary", "date_secondary", "date_volume",
        "date_source", "path_type",
    ]

    with open(CSV_PATH, "w", newline="", encoding="utf-8") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        for root, _, files in os.walk(SOURCE_DIR):
            # Capture the numeric label from the folder name
            parent_folder_name = os.path.basename(root) 
            
            for file in files:
                if file.lower().endswith(".iso"):
                    iso_path = os.path.join(root, file)
                    iso_name_no_ext = os.path.splitext(file)[0]
                    
                    # New Naming: {Number}_{ISO_Name}
                    new_folder_name = f"{parent_folder_name}_{iso_name_no_ext}"
                    out_folder = os.path.join(DEST_DIR, clean_name(new_folder_name))
                    
                    os.makedirs(safe_path(out_folder), exist_ok=True)
                    print(f"Processing: {iso_path} -> {new_folder_name}")

                    try:
                        # Pass the parent_folder_name into the extraction logic
                        extract_iso(iso_path, out_folder, writer, parent_folder_name)
                    except Exception as e:
                        log_error(f"FATAL | {iso_path} | {str(e)}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Processing: G:\thecall\done\12\Call 07-25-08-01.iso -> 12_Call 07-25-08-01
#   Path namespace: joliet_path
# Processing: G:\thecall\done\13\Call 08-08-08-15.iso -> 13_Call 08-08-08-15
#   Path namespace: joliet_path
# Processing: G:\thecall\done\14\Call 08-22-08-29.iso -> 14_Call 08-22-08-29
#   Path namespace: joliet_path
# Processing: G:\thecall\done\15\Call 09-05.iso -> 15_Call 09-05
#   Path namespace: joliet_path
# Processing: G:\thecall\done\16\09-13 Call.iso -> 16_09-13 Call
#   Path namespace: joliet_path
# Processing: G:\thecall\done\17\10-03 Call.iso -> 17_10-03 Call
#   Path namespace: joliet_path
# Processing: G:\thecall\done\1\05-02 Call.iso -> 1_05-02 Call
#   Path namespace: joliet_path
# Processing: G:\thecall\done\2\CALL 04-18-04-25.ISO -> 2_CALL 04-18-04-25
#   Path namespace: joliet_path
# Processing: G:\thecall\done\3\CALL 04-04-04-11.ISO -> 3_CALL 04-04-04-11
#   Path namespace: joliet_path
# Processing: G:\thecall\done\4\Call 05-09.iso -> 4_Call 05-09
#   Path namespace: joliet_path
# Processing: G:\thecall\done\5\Call 05-16.iso -> 5_Call 05-16
#   Path namespace: joliet_path
# Processing: G:\thecall\done\6\Call 05-23.iso -> 6_Call 05-23
#   Path namespace: joliet_path
# Processing: G:\thecall\done\7\Call 05-30.iso -> 7_Call 05-30
#   Path namespace: joliet_path
# Processing: G:\thecall\done\8\Call 06-06.iso -> 8_Call 06-06
#   Path namespace: joliet_path
# Processing: G:\thecall\done\9\Call 06-13-06-20.iso -> 9_Call 06-13-06-20
#   Path namespace: joliet_path
# Processing: G:\thecall\done\10\CALL 06-27-07-04.iso -> 10_CALL 06-27-07-04
#   Path namespace: joliet_path
# Processing: G:\thecall\done\11\CALL 07-11-07-18.iso -> 11_CALL 07-11-07-18
#   Path namespace: joliet_path
# Processing: G:\thecall\done\18\Call 09-20-09-26.iso -> 18_Call 09-20-09-26
#   Path namespace: joliet_path
# Processing: G:\thecall\done\19\Call 10-10.iso -> 19_Call 10-10
#   Path namespace: joliet_path
# Processing: G:\thecall\done\20\Call 10-17.iso -> 20_Call 10-17
#   Path namespace: joliet_path
# Processing: G:\thecall\done\21\Call 10-24.iso -> 21_Call 10-24
#   Path namespace: joliet_path
# Processing: G:\thecall\done\22\Call 10-31.iso -> 22_Call 10-31
#   Path namespace: joliet_path
# Processing: G:\thecall\done\23\Call 11-07.iso -> 23_Call 11-07
#   Path namespace: joliet_path
# Processing: G:\thecall\done\24\Call 11-14.iso -> 24_Call 11-14
#   Path namespace: joliet_path
# Processing: G:\thecall\done\25\Call 11-21.iso -> 25_Call 11-21
#   Path namespace: joliet_path
# Processing: G:\thecall\done\26\Call 11-28.iso -> 26_Call 11-28
#   Path namespace: joliet_path
# Processing: G:\thecall\done\27\Call 12-05.iso -> 27_Call 12-05
#   Path namespace: joliet_path
# Processing: G:\thecall\done\28\Call 12-12.iso -> 28_Call 12-12
#   Path namespace: joliet_path
# Processing: G:\thecall\done\29\Call 12-19.iso -> 29_Call 12-19
#   Path namespace: joliet_path
# Processing: G:\thecall\done\30\Call 12-26.iso -> 30_Call 12-26
#   Path namespace: joliet_path
# Processing: G:\thecall\done\33\33 Call 01-23-01.iso -> 33_33 Call 01-23-01
#   Path namespace: joliet_path
# Processing: G:\thecall\done\34\34 Call 02-06-02.iso -> 34_34 Call 02-06-02
#   Path namespace: joliet_path
# Processing: G:\thecall\done\31\Call 01-02.iso -> 31_Call 01-02
#   Path namespace: joliet_path
# Processing: G:\thecall\done\32\32 Call 01-09-0-.iso -> 32_32 Call 01-09-0-
#   Path namespace: joliet_path
# Processing: G:\thecall\done\44\44 Call 07-02-07.iso -> 44_44 Call 07-02-07
#   Path namespace: joliet_path
# Processing: G:\thecall\done\45\45 Call 07-23-07.iso -> 45_45 Call 07-23-07
#   Path namespace: joliet_path
# Processing: G:\thecall\done\46\46 Call 08-06-08.iso -> 46_46 Call 08-06-08
#   Path namespace: joliet_path
# Processing: G:\thecall\done\47\47 Call 08-20-09.iso -> 47_47 Call 08-20-09
#   Path namespace: joliet_path
# Processing: G:\thecall\done\48\48 Call 09-10-09.iso -> 48_48 Call 09-10-09
#   Path namespace: joliet_path
# Processing: G:\thecall\done\35\35 Call 02-20-02.iso -> 35_35 Call 02-20-02
#   Path namespace: joliet_path
# Processing: G:\thecall\done\36\36 Call 03-05-03.iso -> 36_36 Call 03-05-03
#   Path namespace: joliet_path
# Processing: G:\thecall\done\37\37 Call 03-26-04.iso -> 37_37 Call 03-26-04
#   Path namespace: joliet_path
# Processing: G:\thecall\done\38\38 Call 04-09-04.iso -> 38_38 Call 04-09-04
#   Path namespace: joliet_path
# Processing: G:\thecall\done\39\39 Call 04-23-04.iso -> 39_39 Call 04-23-04
#   Path namespace: joliet_path
# Processing: G:\thecall\done\40\40 Call 05-07-05.iso -> 40_40 Call 05-07-05
#   Path namespace: joliet_path
# Processing: G:\thecall\done\41\41 Call 05-21-05.iso -> 41_41 Call 05-21-05
#   Path namespace: joliet_path
# Processing: G:\thecall\done\42\42 CALL 06-04-06.iso -> 42_42 CALL 06-04-06
#   Path namespace: joliet_path
# Processing: G:\thecall\done\43\43 Call 06-18-06.iso -> 43_43 Call 06-18-06
#   Path namespace: joliet_path
# Processing: G:\thecall\done\49\49 Call 09-24-10.iso -> 49_49 Call 09-24-10
#   Path namespace: joliet_path
# Processing: G:\thecall\done\60\February 4-10.iso -> 60_February 4-10
#   Path namespace: joliet_path
# Processing: G:\thecall\done\61\February 11-24.iso -> 61_February 11-24
#   Path namespace: joliet_path
# Processing: G:\thecall\done\62\Feb25-March 03.iso -> 62_Feb25-March 03
#   Path namespace: joliet_path
# Processing: G:\thecall\done\63\March 04-17.iso -> 63_March 04-17
#   Path namespace: joliet_path
# Processing: G:\thecall\done\64\March 18-24.iso -> 64_March 18-24
#   Path namespace: joliet_path
# Processing: G:\thecall\done\50\50 Call 10-08-10.iso -> 50_50 Call 10-08-10
#   Path namespace: joliet_path
# Processing: G:\thecall\done\51\51 Call 10-22-10.iso -> 51_51 Call 10-22-10
#   Path namespace: joliet_path
# Processing: G:\thecall\done\52\52 Call 11-05-11.iso -> 52_52 Call 11-05-11
#   Path namespace: joliet_path
# Processing: G:\thecall\done\53\53 Call 11-19-11.iso -> 53_53 Call 11-19-11
#   Path namespace: joliet_path
# Processing: G:\thecall\done\54\54 Call 12-03-12.iso -> 54_54 Call 12-03-12
#   Path namespace: joliet_path
# Processing: G:\thecall\done\55\55 Call 12-17.iso -> 55_55 Call 12-17
#   Path namespace: joliet_path
# Processing: G:\thecall\done\56\56 Call 12-24.iso -> 56_56 Call 12-24
#   Path namespace: joliet_path
# Processing: G:\thecall\done\57\57 Call 12-31.iso -> 57_57 Call 12-31
#   Path namespace: joliet_path
# Processing: G:\thecall\done\58\Jan 7-20.iso -> 58_Jan 7-20
#   Path namespace: joliet_path
# Processing: G:\thecall\done\59\Jan.iso -> 59_Jan
#   Path namespace: joliet_path
# Processing: G:\thecall\done\77\July 29 - Aug 11.iso -> 77_July 29 - Aug 11
#   Path namespace: joliet_path
# Processing: G:\thecall\done\78\August 12-18.iso -> 78_August 12-18
#   Path namespace: joliet_path
# Processing: G:\thecall\done\79\August 19-25..iso -> 79_August 19-25.
#   Path namespace: joliet_path
# Processing: G:\thecall\done\80\Aug 26 - Sept 8.iso -> 80_Aug 26 - Sept 8
#   Path namespace: joliet_path
# Processing: G:\thecall\done\65\March 25-31.iso -> 65_March 25-31
#   Path namespace: joliet_path
# Processing: G:\thecall\done\66\April 1-7.iso -> 66_April 1-7
#   Path namespace: joliet_path
# Processing: G:\thecall\done\67\untitled.iso -> 67_untitled
#   Path namespace: joliet_path
# Processing: G:\thecall\done\68\April 22- May 5.iso -> 68_April 22- May 5
#   Path namespace: joliet_path
# Processing: G:\thecall\done\69\untitled(1).iso -> 69_untitled(1)
#   Path namespace: joliet_path
# Processing: G:\thecall\done\70\May 13-19.iso -> 70_May 13-19
#   Path namespace: joliet_path
# Processing: G:\thecall\done\71\May 20-26.iso -> 71_May 20-26
#   Path namespace: joliet_path
# Processing: G:\thecall\done\72\untitled(2).iso -> 72_untitled(2)
#   Path namespace: joliet_path
# Processing: G:\thecall\done\73\untitled(3).iso -> 73_untitled(3)
#   Path namespace: joliet_path
# Processing: G:\thecall\done\74\untitled(4).iso -> 74_untitled(4)
#   Path namespace: joliet_path
# Processing: G:\thecall\done\75\July 1-7 and 8-1.iso -> 75_July 1-7 and 8-1
#   Path namespace: joliet_path
# Processing: G:\thecall\done\76\July 15-21 and 2.iso -> 76_July 15-21 and 2
#   Path namespace: joliet_path
# Processing: G:\thecall\done\95\Feb 10.iso -> 95_Feb 10
#   Path namespace: joliet_path
# Processing: G:\thecall\done\96\Feb 17-23.iso -> 96_Feb 17-23
#   Path namespace: joliet_path
# Processing: G:\thecall\done\81\Sept 09-15.iso -> 81_Sept 09-15
#   Path namespace: joliet_path
# Processing: G:\thecall\done\82\Sept 16-29.iso -> 82_Sept 16-29
#   Path namespace: joliet_path
# Processing: G:\thecall\done\83\Sept 30 - Oct. 1.iso -> 83_Sept 30 - Oct. 1
#   Path namespace: joliet_path
# Processing: G:\thecall\done\84\Oct. 14 - 27.iso -> 84_Oct. 14 - 27
#   Path namespace: joliet_path
# Processing: G:\thecall\done\85\Oct 28 - Nov. 10.iso -> 85_Oct 28 - Nov. 10
#   Path namespace: joliet_path
# Processing: G:\thecall\done\86\Nov 11-17.iso -> 86_Nov 11-17
#   Path namespace: joliet_path
# Processing: G:\thecall\done\87\Nov. 18-24.iso -> 87_Nov. 18-24
#   Path namespace: joliet_path
# Processing: G:\thecall\done\88\Nov. 25- Dec 8.iso -> 88_Nov. 25- Dec 8
#   Path namespace: joliet_path
# Processing: G:\thecall\done\89\untitled(5).iso -> 89_untitled(5)
#   Path namespace: joliet_path
# Processing: G:\thecall\done\90\Dec 16-22.iso -> 90_Dec 16-22
#   Path namespace: joliet_path
# Processing: G:\thecall\done\91\Dec 23 - Jan 05.iso -> 91_Dec 23 - Jan 05
#   Path namespace: joliet_path
# Processing: G:\thecall\done\92\Jan 6-19.iso -> 92_Jan 6-19
#   Path namespace: joliet_path
# Processing: G:\thecall\done\93\Jan 20 - Feb 2.iso -> 93_Jan 20 - Feb 2
#   Path namespace: joliet_path
# Processing: G:\thecall\done\94\Feb 3-9.iso -> 94_Feb 3-9
#   Path namespace: joliet_path
# Processing: G:\thecall\done\106\untitled(7).iso -> 106_untitled(7)
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\106_untitled(7)\untitled(7).iso
# Processing: G:\thecall\done\107\May 26 - June 1.iso -> 107_May 26 - June 1
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\107_May 26 - June 1\May 26 - June 1.iso
# Processing: G:\thecall\done\97\untitled(6).iso -> 97_untitled(6)
#   Path namespace: joliet_path
# Processing: G:\thecall\done\98\Mar 3-16.iso -> 98_Mar 3-16
#   Path namespace: joliet_path
# Processing: G:\thecall\done\99\Mar 17-23.iso -> 99_Mar 17-23
#   Path namespace: joliet_path
# Processing: G:\thecall\done\100\Mar 24-30.iso -> 100_Mar 24-30
#   Path namespace: joliet_path
# Processing: G:\thecall\done\101\Mar 31 - April 6.iso -> 101_Mar 31 - April 6
#   Path namespace: joliet_path
# Processing: G:\thecall\done\102\April 7-20.iso -> 102_April 7-20
#   Path namespace: joliet_path
# Processing: G:\thecall\done\103\April 21 - May 4.iso -> 103_April 21 - May 4
#   Path namespace: joliet_path
# Processing: G:\thecall\done\104\May 5.iso -> 104_May 5
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\104_May 5\May 5.iso
# Processing: G:\thecall\done\105\May 12.iso -> 105_May 12
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\105_May 12\May 12.iso
# Processing: G:\thecall\done\118\Aug 04.iso -> 118_Aug 04
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\118_Aug 04\Aug 04.iso
# Processing: G:\thecall\done\119\Aug 11- 24.iso -> 119_Aug 11- 24
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\119_Aug 11- 24\Aug 11- 24.iso
# Processing: G:\thecall\done\120\Aug 25-31.iso -> 120_Aug 25-31
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\120_Aug 25-31\Aug 25-31.iso
# Processing: G:\thecall\done\108\June 2-8.iso -> 108_June 2-8
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\108_June 2-8\June 2-8.iso
# Processing: G:\thecall\done\109\untitled.iso -> 109_untitled
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\109_untitled\untitled.iso
# Processing: G:\thecall\done\110\June 16-22.iso -> 110_June 16-22
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\110_June 16-22\June 16-22.iso
# Processing: G:\thecall\done\111\June 23 - 29.iso -> 111_June 23 - 29
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\111_June 23 - 29\June 23 - 29.iso
# Processing: G:\thecall\done\112\June 30 - July 6.iso -> 112_June 30 - July 6
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\112_June 30 - July 6\June 30 - July 6.iso
# Processing: G:\thecall\done\113\July 7 - 20.iso -> 113_July 7 - 20
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\113_July 7 - 20\July 7 - 20.iso
# Processing: G:\thecall\done\114\July 21 - 27.iso -> 114_July 21 - 27
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\114_July 21 - 27\July 21 - 27.iso
# Processing: G:\thecall\done\115\July 28.iso -> 115_July 28
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\115_July 28\July 28.iso
# Processing: G:\thecall\done\116\Special Section.iso -> 116_Special Section
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\116_Special Section\Special Section.iso
# Processing: G:\thecall\done\117\Aug 04-10 #1.iso -> 117_Aug 04-10 #1
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\117_Aug 04-10 #1\Aug 04-10 #1.iso
# Processing: G:\thecall\done\129\Oct 27 - Nov 2.iso -> 129_Oct 27 - Nov 2
#   Path namespace: joliet_path
# Processing: G:\thecall\done\130\Nov 3.iso -> 130_Nov 3
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\130_Nov 3\Nov 3.iso
# Processing: G:\thecall\done\121\Sept. 1-7.iso -> 121_Sept. 1-7
#   Path namespace: joliet_path
# Processing: G:\thecall\done\122\Sept 8-14.iso -> 122_Sept 8-14
#   Path namespace: joliet_path
# Processing: G:\thecall\done\123\Sept 15-21.iso -> 123_Sept 15-21
#   Path namespace: joliet_path
# Processing: G:\thecall\done\124\Sept 22-28.iso -> 124_Sept 22-28
#   Path namespace: joliet_path
# Processing: G:\thecall\done\125\Sept 29 - Oct 5.iso -> 125_Sept 29 - Oct 5
#   Path namespace: joliet_path
# Processing: G:\thecall\done\126\Oct 6-12.iso -> 126_Oct 6-12
#   Path namespace: joliet_path
# Processing: G:\thecall\done\127\Oct 13-19.iso -> 127_Oct 13-19
#   Path namespace: joliet_path
# Processing: G:\thecall\done\128\Oct 20-26.iso -> 128_Oct 20-26
#   Path namespace: joliet_path
# Processing: G:\thecall\done\138\Feb 12-Mar 01.iso -> 138_Feb 12-Mar 01
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\138_Feb 12-Mar 01\Feb 12-Mar 01.iso
# Processing: G:\thecall\done\139\March 02-08.iso -> 139_March 02-08
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\153_Untitled CD\Untitled CD.iso
# Processing: G:\thecall\done\154\Aug 3-9.iso -> 154_Aug 3-9
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\154_Aug 3-9\Aug 3-9.iso
# Processing: G:\thecall\done\155\Aug 10-16.iso -> 155_Aug 10-16
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\155_Aug 10-16\Aug 10-16.iso
# Processing: G:\thecall\done\156\Aug 17-23.iso -> 156_Aug 17-23
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\156_Aug 17-23\Aug 17-23.iso
# Processing: G:\thecall\done\157\Aug 24-30.iso -> 157_Aug 24-30
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\157_Aug 24-30\Aug 24-30.iso
# Processing: G:\thecall\done\158\Aug 31 - Sept 06.iso -> 158_Aug 31 - Sept 06
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\158_Aug 31 - Sept 06\Aug 31 - Sept 06.iso
# Processing: G:\thecall\done\167\Oct 26-Nov 1.iso -> 167_Oct 26-Nov 1
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\167_Oct 26-Nov 1\Oct 26-Nov 1.iso
# Processing: G:\thecall\done\168\Nov 2-8.iso -> 168_Nov 2-8
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\168_Nov 2-8\Nov 2-8.iso
# Processing: G:\thecall\done\169\Nov 9-15.iso -> 169_Nov 9-15
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\169_Nov 9-15\Nov 9-15.iso
# Processing: G:\thecall\done\170\Nov 9-15 pt 2.iso -> 170_Nov 9-15 pt 2
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\170_Nov 9-15 pt 2\Nov 9-15 pt 2.iso
# Processing: G:\thecall\done\162\Sept 14-20.iso -> 162_Sept 14-20
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\162_Sept 14-20\Sept 14-20.iso
# Processing: G:\thecall\done\163\Sept 21-27.iso -> 163_Sept 21-27
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\163_Sept 21-27\Sept 21-27.iso
# Processing: G:\thecall\done\164\Sept 28-Oct 4.iso -> 164_Sept 28-Oct 4
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\164_Sept 28-Oct 4\Sept 28-Oct 4.iso
# Processing: G:\thecall\done\165\Oct 5-18.iso -> 165_Oct 5-18
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\165_Oct 5-18\Oct 5-18.iso
# Processing: G:\thecall\done\166\Oct 19-25.iso -> 166_Oct 19-25
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\166_Oct 19-25\Oct 19-25.iso
# Processing: G:\thecall\done\181\Jan 25-31.iso -> 181_Jan 25-31
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\181_Jan 25-31\Jan 25-31.iso
# Processing: G:\thecall\done\182\Feb 01-07 pt 1.iso -> 182_Feb 01-07 pt 1
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\182_Feb 01-07 pt 1\Feb 01-07 pt 1.iso
# Processing: G:\thecall\done\183\Feb 1-7 pt 2.iso -> 183_Feb 1-7 pt 2
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\183_Feb 1-7 pt 2\Feb 1-7 pt 2.iso
# Processing: G:\thecall\done\171\Nov 16-22.iso -> 171_Nov 16-22
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\171_Nov 16-22\Nov 16-22.iso
# Processing: G:\thecall\done\172\Untitled CD(1).iso -> 172_Untitled CD(1)
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\172_Untitled CD(1)\Untitled CD(1).iso
# Processing: G:\thecall\done\173\Nov 30- Dec 6.iso -> 173_Nov 30- Dec 6
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\173_Nov 30- Dec 6\Nov 30- Dec 6.iso
# Processing: G:\thecall\done\174\Dec 7-13.iso -> 174_Dec 7-13
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\174_Dec 7-13\Dec 7-13.iso
# Processing: G:\thecall\done\175\Dec 14-20.iso -> 175_Dec 14-20
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\175_Dec 14-20\Dec 14-20.iso
# Processing: G:\thecall\done\176\Dec 21-27.iso -> 176_Dec 21-27
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\198_Untitled CD\Untitled CD.iso
# Processing: G:\thecall\done\199\April 11-17.iso -> 199_April 11-17
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\199_April 11-17\April 11-17.iso
# Processing: G:\thecall\done\200\April 11-17(1).iso -> 200_April 11-17(1)
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\200_April 11-17(1)\April 11-17(1).iso
# Processing: G:\thecall\done\201\April 18-24.iso -> 201_April 18-24
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\201_April 18-24\April 18-24.iso
# Processing: G:\thecall\done\202\April 18-24(1).iso -> 202_April 18-24(1)
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\202_April 18-24(1)\April 18-24(1).iso
# Processing: G:\thecall\done\203\April 25-May 01.iso -> 203_April 25-May 01
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\203_April 25-May 01\April 25-May 01.iso
# Processing: G:\thecall\done\204\April 25-May 01(1).iso -> 204_April 25-May 01(1)
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\204_April 25-May 01(1)\April 25-May 01(1).iso
# Processing: G:\thecall\done\205\May 02-08 pt1.iso -> 205_May 02-08 pt1
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\205_May 02-08 pt1\May 02-08 pt1.iso
# Processing: G:\thecall\done\206\May 02-08 pt2.iso -> 206_May 02-08 pt2
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\206_May 02-08 pt2\May 02-08 pt2.iso
# Processing: G:\thecall\done\207\May 09-15 pt1.iso -> 207_May 09-15 pt1
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\207_May 09-15 pt1\May 09-15 pt1.iso
# Processing: G:\thecall\done\208\May 09-15 pt2.iso -> 208_May 09-15 pt2
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\208_May 09-15 pt2\May 09-15 pt2.iso
# Processing: G:\thecall\done\209\May09-15 pt3.iso -> 209_May09-15 pt3
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\209_May09-15 pt3\May09-15 pt3.iso
# Processing: G:\thecall\done\210\May 16-22 pt1.iso -> 210_May 16-22 pt1
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\210_May 16-22 pt1\May 16-22 pt1.iso
# Processing: G:\thecall\done\211\May 16-22 pt2.iso -> 211_May 16-22 pt2
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\211_May 16-22 pt2\May 16-22 pt2.iso
# Processing: G:\thecall\done\212\May 23-29 pt1.iso -> 212_May 23-29 pt1
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\212_May 23-29 pt1\May 23-29 pt1.iso
# Processing: G:\thecall\done\213\May23-29 pt2.iso -> 213_May23-29 pt2
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\213_May23-29 pt2\May23-29 pt2.iso
# Processing: G:\thecall\done\214\May 30 - June 05 pt1.iso -> 214_May 30 - June 05 pt1
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\214_May 30 - June 05 pt1\May 30 - June 05 pt1.iso
# Processing: G:\thecall\done\215\May 30-June 05 pt2.iso -> 215_May 30-June 05 pt2
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\215_May 30-June 05 pt2\May 30-June 05 pt2.iso
# Processing: G:\thecall\done\216\June 6-12 pt 1.iso -> 216_June 6-12 pt 1
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\216_June 6-12 pt 1\June 6-12 pt 1.iso
# Processing: G:\thecall\done\217\June 6-12 pt2.iso -> 217_June 6-12 pt2
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\217_June 6-12 pt2\June 6-12 pt2.iso
# Processing: G:\thecall\done\218\June 13-19 pt1.iso -> 218_June 13-19 pt1
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\218_June 13-19 pt1\June 13-19 pt1.iso
# Processing: G:\thecall\done\219\June 13-19 pt2.iso -> 219_June 13-19 pt2
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\219_June 13-19 pt2\June 13-19 pt2.iso
# Processing: G:\thecall\done\220\June 20-26 pt1.iso -> 220_June 20-26 pt1
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\220_June 20-26 pt1\June 20-26 pt1.iso
# Processing: G:\thecall\done\221\June 20-26 pt2.iso -> 221_June 20-26 pt2
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\333_July 03-09 10-16 complete\July 03-09 10-16 complete.iso
# Processing: G:\thecall\done\334\July 17-23 (missing kck17) 24-30.iso -> 334_July 17-23 (missing kck17) 24-30
#   Path namespace: joliet_path
# Processing: G:\thecall\done\335\July 31-Aug 06 Complete.iso -> 335_July 31-Aug 06 Complete
#   Path namespace: joliet_path
# Processing: G:\thecall\done\336\Aug 07-13 14-20.iso -> 336_Aug 07-13 14-20
#   Path namespace: joliet_path
# Processing: G:\thecall\done\337\August 21-27 28-Sept 03 .iso -> 337_August 21-27 28-Sept 03
#   Path namespace: joliet_path
# Processing: G:\thecall\done\338\Setember 04-10 11-17.iso -> 338_Setember 04-10 11-17
#   Path namespace: joliet_path
# Processing: G:\thecall\done\339\September 18-24 25- Oct 1.iso -> 339_September 18-24 25- Oct 1
#   Path namespace: joliet_path
# Processing: G:\thecall\done\340\October 02-08 09-15 Complete.iso -> 340_October 02-08 09-15 Complete
#   Path namespace: joliet_path
# Processing: G:\thecall\done\341\October 16-22 23-29 complete.iso -> 341_October 16-22 23-29 complete
#   Path namespace: joliet_path
# Processing: G:\thecall\done\342\Oct 30 - Nov 05.iso -> 342_Oct 30 - Nov 05
#   Path namespace: joliet_path
# Processing: G:\thecall\done\343\November 06-12 13-19 Complete.iso -> 343_November 06-12 13-19 Complete
#   Path namespace: joliet_path
# Processing: G:\thecall\done\344\Novemeber 20-26 27-December 03.iso -> 344_Novemeber 20-26 27-December 03
#   Path namespace: joliet_path
# Processing: G:\thecall\done\345\Decemeber 04-10 11-17.iso -> 345_Decemeber 04-10 11-17
#   Path namespace: joliet_path
# Processing: G:\thecall\done\346\December 18-24 25-1 complete.iso -> 346_December 18-24 25-1 complete
#   Path namespace: joliet_path
# Processing: G:\thecall\done\347\January 01-07 08-14.iso -> 347_January 01-07 08-14
#   Path namespace: joliet_path
# Processing: G:\thecall\done\348\January 15-21 22-28 complete.iso -> 348_January 15-21 22-28 complete
#   Path namespace: joliet_path
# Processing: G:\thecall\done\349\January 29 - Feb 04.iso -> 349_January 29 - Feb 04
#   Path namespace: joliet_path
# Processing: G:\thecall\done\350\February 05-11 12-18 complete.iso -> 350_February 05-11 12-18 complete
#   Path namespace: joliet_path
# Processing: G:\thecall\done\351\February 19-25 26-March 04.iso -> 351_February 19-25 26-March 04
#   Path namespace: joliet_path
# Processing: G:\thecall\done\352\March 05-11 12-18.iso -> 352_March 05-11 12-18
#   Path namespace: joliet_path
# Processing: G:\thecall\done\352A\March 19-25 broken .iso -> 352A_March 19-25 broken
#   Path namespace: joliet_path
# Processing: G:\thecall\done\353\March 26 - April 01.iso -> 353_March 26 - April 01
#   Path namespace: joliet_path
# Processing: G:\thecall\done\354\April 02-08 09-15.iso -> 354_April 02-08 09-15
#   Path namespace: joliet_path
# Processing: G:\thecall\done\355\April 16-22 23-29 .iso -> 355_April 16-22 23-29
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\355_April 16-22 23-29\April 16-22 23-29 .iso
# Processing: G:\thecall\done\356\April 30 - May 06.iso -> 356_April 30 - May 06
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\356_April 30 - May 06\April 30 - May 06.iso
# Processing: G:\thecall\done\357\May 07-13 14-20.iso -> 357_May 07-13 14-20
#   Path namespace: joliet_path
# Processing: G:\thecall\done\358\May 21-27 28- June 0.iso -> 358_May 21-27 28- June 0
#   Path namespace: joliet_path
# Processing: G:\thecall\done\359\June 04-10 11-17.iso -> 359_June 04-10 11-17
#   Path namespace: joliet_path
# Processing: G:\thecall\done\360\June 25- July 1.iso -> 360_June 25- July 1
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\360_June 25- July 1\June 25- July 1.iso
# Processing: G:\thecall\done\361\July 02-08 09-15.iso -> 361_July 02-08 09-15
#   Path namespace: joliet_path
# Processing: G:\thecall\done\362\July 16-22 23-29.iso -> 362_July 16-22 23-29
#   Path namespace: joliet_path
# Processing: G:\thecall\done\363\July 30-Aug 05.iso -> 363_July 30-Aug 05
#   Path namespace: joliet_path
# Processing: G:\thecall\done\364\Aug 06-12 13-19.iso -> 364_Aug 06-12 13-19
#   Path namespace: joliet_path
# Processing: G:\thecall\done\365\August 20-26 27-September 02.iso -> 365_August 20-26 27-September 02
#   Path namespace: joliet_path
# Processing: G:\thecall\done\366\September 03-09 10-16 .iso -> 366_September 03-09 10-16
#   Path namespace: joliet_path
# Processing: G:\thecall\done\367\September 17-23 24-30.iso -> 367_September 17-23 24-30
#   Path namespace: joliet_path
# Processing: G:\thecall\done\368\October 01-07 08-14.iso -> 368_October 01-07 08-14
#   Path namespace: joliet_path
# Processing: G:\thecall\done\369\October 15-21 22-28.iso -> 369_October 15-21 22-28
#   Path namespace: joliet_path
# Processing: G:\thecall\done\370\October 29 November 04.iso -> 370_October 29 November 04
#   Path namespace: joliet_path
# Processing: G:\thecall\done\371\Untitled DVD.iso -> 371_Untitled DVD
#   Path namespace: joliet_path
# Processing: G:\thecall\done\372\November 19-25 26-December 02.iso -> 372_November 19-25 26-December 02
#   Path namespace: joliet_path
# Processing: G:\thecall\done\373\Dec 03-09 10-16.iso -> 373_Dec 03-09 10-16
#   Path namespace: joliet_path
# Processing: G:\thecall\done\374\Dec 17-23 24-30.iso -> 374_Dec 17-23 24-30
#   Path namespace: joliet_path
# Processing: G:\thecall\done\375\Dec 31- Jan 06.iso -> 375_Dec 31- Jan 06
#   Path namespace: joliet_path
# Processing: G:\thecall\done\376\January 07-13 14-20.iso -> 376_January 07-13 14-20
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\376_January 07-13 14-20\January 07-13 14-20.iso
# Processing: G:\thecall\done\377\Jan 21-27 28-Feb 03.iso -> 377_Jan 21-27 28-Feb 03
#   Path namespace: joliet_path
# Processing: G:\thecall\done\378_broken\Feb 04-10 11-17.iso -> 378_broken_Feb 04-10 11-17
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\378_broken_Feb 04-10 11-17\Feb 04-10 11-17.iso
# Processing: G:\thecall\done\379\Feb 18-24 25-Mar 03.iso -> 379_Feb 18-24 25-Mar 03
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\379_Feb 18-24 25-Mar 03\Feb 18-24 25-Mar 03.iso
# Processing: G:\thecall\done\380\March 04-10 11-17.iso -> 380_March 04-10 11-17
#   Path namespace: joliet_path
# Processing: G:\thecall\done\381\March 18-24 25-31.iso -> 381_March 18-24 25-31
#   Path namespace: joliet_path
# Processing: G:\thecall\done\382\April 01-07 08-14.iso -> 382_April 01-07 08-14
#   Path namespace: joliet_path
# Processing: G:\thecall\done\383\April 15-21 22-28.iso -> 383_April 15-21 22-28
#   Path namespace: joliet_path
# Processing: G:\thecall\done\384\April 29.iso -> 384_April 29
#   Path namespace: joliet_path
# Processing: G:\thecall\done\385\May o6-12 13-19.iso -> 385_May o6-12 13-19
#   Path namespace: joliet_path
# Processing: G:\thecall\done\386\May 20-26 27-June 02.iso -> 386_May 20-26 27-June 02
#   Path namespace: joliet_path
# Processing: G:\thecall\done\387\June 03-09 10-16.iso -> 387_June 03-09 10-16
#   Path namespace: joliet_path
# Processing: G:\thecall\done\388\June 17-23 24-30.iso -> 388_June 17-23 24-30
#   Path namespace: joliet_path
# Processing: G:\thecall\done\389\July 01-07 08-14.iso -> 389_July 01-07 08-14
#   Path namespace: joliet_path
# Processing: G:\thecall\done\390\July 15-21 22-28.iso -> 390_July 15-21 22-28
#   Path namespace: joliet_path
# Processing: G:\thecall\done\391\july 29-aug 04.iso -> 391_july 29-aug 04
#   Path namespace: joliet_path
# Processing: G:\thecall\done\392\August 5-11 12-18.iso -> 392_August 5-11 12-18
#   Path namespace: joliet_path
# Processing: G:\thecall\done\393\August 19-25 26-01.iso -> 393_August 19-25 26-01
#   Path namespace: joliet_path
# Processing: G:\thecall\done\394\September 02-08 09-15.iso -> 394_September 02-08 09-15
#   Path namespace: joliet_path
# Processing: G:\thecall\done\395\September 16-22 23-29 Oct 30-6.iso -> 395_September 16-22 23-29 Oct 30-6
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\395_September 16-22 23-29 Oct 30-6\September 16-22 23-29 Oct 30-6.iso
# Processing: G:\thecall\done\396\Oct 7-13 14-20.iso -> 396_Oct 7-13 14-20
#   Path namespace: joliet_path
# Processing: G:\thecall\done\397\Oct 21-27 28-Nov 3.iso -> 397_Oct 21-27 28-Nov 3
#   Path namespace: joliet_path
# Processing: G:\thecall\done\398\Nov 04-10 11-17.iso -> 398_Nov 04-10 11-17
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\398_Nov 04-10 11-17\Nov 04-10 11-17.iso
# Processing: G:\thecall\done\399\Nov 18-24 25-.iso -> 399_Nov 18-24 25-
#   Path namespace: joliet_path
# Processing: G:\thecall\done\400\Dec 02-08 09-15.iso -> 400_Dec 02-08 09-15
#   Path namespace: joliet_path
# Processing: G:\thecall\done\401\Dec 16-22 23-29 30-Jan 05.iso -> 401_Dec 16-22 23-29 30-Jan 05
#   Path namespace: joliet_path
# Processing: G:\thecall\done\402\January 06-12 13-19.iso -> 402_January 06-12 13-19
#   Path namespace: joliet_path
# Processing: G:\thecall\done\403\Jan 20-feb 02.iso -> 403_Jan 20-feb 02
#   Path namespace: joliet_path
# Processing: G:\thecall\done\404\Feb 03-16 .iso -> 404_Feb 03-16
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\404_Feb 03-16\Feb 03-16 .iso
# Processing: G:\thecall\done\405\February 17-23 24 March 01.iso -> 405_February 17-23 24 March 01
#   Path namespace: joliet_path
# Processing: G:\thecall\done\406\March 2-8 9-15.iso -> 406_March 2-8 9-15
#   Path namespace: joliet_path
# Processing: G:\thecall\done\407\March 16-22 23-29 30-April 05.iso -> 407_March 16-22 23-29 30-April 05
#   Path namespace: joliet_path
# Processing: G:\thecall\done\408\APRIL 06-12 13-19.iso -> 408_APRIL 06-12 13-19
#   Path namespace: joliet_path
# Processing: G:\thecall\done\409\April 20-26 April 27-May 03.iso -> 409_April 20-26 April 27-May 03
#   Path namespace: joliet_path
# Processing: G:\thecall\done\410\May 04-31.iso -> 410_May 04-31
#   Path namespace: joliet_path
# Processing: G:\thecall\done\411\June01-July 05.iso -> 411_June01-July 05
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\411_June01-July 05\June01-July 05.iso
# Processing: G:\thecall\done\412\July06-Aug02.iso -> 412_July06-Aug02
#   Path namespace: joliet_path
# Processing: G:\thecall\done\413\Aug 4-31.iso -> 413_Aug 4-31
#   Path namespace: joliet_path
# Processing: G:\thecall\done\414\September 7- October 4.iso -> 414_September 7- October 4
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\414_September 7- October 4\September 7- October 4.iso
# Processing: G:\thecall\done\415\October 05-November 01.iso -> 415_October 05-November 01
#   Path namespace: joliet_path
# Processing: G:\thecall\done\416\November02-December 06.iso -> 416_November02-December 06
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\416_November02-December 06\November02-December 06.iso
# Processing: G:\thecall\done\417\Dec07-Jan03.iso -> 417_Dec07-Jan03
#   Path namespace: joliet_path
# Processing: G:\thecall\done\418\January 04-31.iso -> 418_January 04-31
#   Path namespace: joliet_path
# Processing: G:\thecall\done\419_broken\February 1-28.iso -> 419_broken_February 1-28
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\419_broken_February 1-28\February 1-28.iso
# Processing: G:\thecall\done\420\March 1-April 4.iso -> 420_March 1-April 4
#   Path namespace: joliet_path
# Processing: G:\thecall\done\421\April 05 - may 02.iso -> 421_April 05 - may 02
#   Path namespace: joliet_path
# Processing: G:\thecall\done\422\May 3- June 06.iso -> 422_May 3- June 06
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\422_May 3- June 06\May 3- June 06.iso
# Processing: G:\thecall\done\423\June 07- July 04.iso -> 423_June 07- July 04
#   Path namespace: joliet_path
# Processing: G:\thecall\done\424\July 5 - August 1.iso -> 424_July 5 - August 1
#   Path namespace: joliet_path
# Processing: G:\thecall\done\425\August 2 thru August 30.iso -> 425_August 2 thru August 30
#   Path namespace: joliet_path
# Processing: G:\thecall\done\426\Sept 06-27.iso -> 426_Sept 06-27
#   Path namespace: joliet_path
# Processing: G:\thecall\done\427\October 04-31.iso -> 427_October 04-31
#   Path namespace: joliet_path
# Processing: G:\thecall\done\428\November 01- December 05.iso -> 428_November 01- December 05
#   Path namespace: joliet_path
# Processing: G:\thecall\done\429\December 06-January 02.iso -> 429_December 06-January 02
#   Path namespace: joliet_path
# Processing: G:\thecall\done\430\January 03- February 06.iso -> 430_January 03- February 06
#   Path namespace: joliet_path
# Processing: G:\thecall\done\431\Feb 07 - Mar 06.iso -> 431_Feb 07 - Mar 06
#   Path namespace: joliet_path
# Processing: G:\thecall\done\432\Mar 07 - Apr 03.iso -> 432_Mar 07 - Apr 03
#   Path namespace: joliet_path
# Processing: G:\thecall\done\433\Apr 04 - May 01.iso -> 433_Apr 04 - May 01
#   Path namespace: joliet_path
# Processing: G:\thecall\done\434\May02-15.iso -> 434_May02-15
#   Path namespace: joliet_path
# Processing: G:\thecall\done\435\May 16 - June 05.iso -> 435_May 16 - June 05
#   Path namespace: joliet_path
# Processing: G:\thecall\done\436\June 6 - july 3.iso -> 436_June 6 - july 3
#   Path namespace: joliet_path
# Processing: G:\thecall\done\437\july 4 - 31.iso -> 437_july 4 - 31
#   Path namespace: joliet_path
# Processing: G:\thecall\done\448\Call 01-03.iso -> 448_Call 01-03
#   Path namespace: joliet_path
# Processing: G:\thecall\done\449\Call 01-24.iso -> 449_Call 01-24
#   Path namespace: joliet_path
# Processing: G:\thecall\done\441\Call 03-28.iso -> 441_Call 03-28
#   Path namespace: joliet_path
# Processing: G:\thecall\done\442\Call 03-14-03-21.iso -> 442_Call 03-14-03-21
#   Path namespace: joliet_path
# Processing: G:\thecall\done\443\Call 2-21-03-07.iso -> 443_Call 2-21-03-07
#   Path namespace: joliet_path
# Processing: G:\thecall\done\444\Call 02-21.iso -> 444_Call 02-21
#   Path namespace: joliet_path
# Processing: G:\thecall\done\445\Call 02-14.iso -> 445_Call 02-14
#   Path namespace: joliet_path
# Processing: G:\thecall\done\446\Call 01-31-02-07.iso -> 446_Call 01-31-02-07
#   Path namespace: joliet_path
# Processing: G:\thecall\done\447\Call 01-10-01-17.iso -> 447_Call 01-10-01-17
#   Path namespace: joliet_path
# Processing: G:\thecall\done\461\Photos(3).iso -> 461_Photos(3)
#   Path namespace: joliet_path
# Processing: G:\thecall\done\462\Photo's to (Disk.iso -> 462_Photo's to (Disk
#   Path namespace: joliet_path
# Processing: G:\thecall\done\462\464\Photos(5).iso -> 464_Photos(5)
#   Path namespace: joliet_path
# Processing: G:\thecall\done\463\Photos(4).iso -> 463_Photos(4)
#   Path namespace: joliet_path
# Processing: G:\thecall\done\450\photos.iso -> 450_photos
#   Path namespace: joliet_path
# Processing: G:\thecall\done\451\Photos(1).iso -> 451_Photos(1)
#   Path namespace: joliet_path
# Processing: G:\thecall\done\452\I SEE DEAD PEOPL.iso -> 452_I SEE DEAD PEOPL
#   Path namespace: joliet_path
# Processing: G:\thecall\done\453\photo's.iso -> 453_photo's
#   Path namespace: joliet_path
# Processing: G:\thecall\done\454\Nov 2006- Dec 2007.iso -> 454_Nov 2006- Dec 2007
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\454_Nov 2006- Dec 2007\Nov 2006- Dec 2007.iso
# Processing: G:\thecall\done\455\Nov 2006 - Feb 2007 Copy.iso -> 455_Nov 2006 - Feb 2007 Copy
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\455_Nov 2006 - Feb 2007 Copy\Nov 2006 - Feb 2007 Copy.iso
# Processing: G:\thecall\done\456\Jun 22 2006.iso -> 456_Jun 22 2006
#   Path namespace: joliet_path
# Processing: G:\thecall\done\457\AasimBaheyadeen.iso -> 457_AasimBaheyadeen
#   Path namespace: joliet_path
# Processing: G:\thecall\done\458\Untitled CD.iso -> 458_Untitled CD
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\458_Untitled CD\Untitled CD.iso
# Processing: G:\thecall\done\459\Nov 2006 - Feb 2007 photo's.iso -> 459_Nov 2006 - Feb 2007 photo's
#   [OPEN_FAIL] Copied raw ISO to: e:\c_out\459_Nov 2006 - Feb 2007 photo's\Nov 2006 - Feb 2007 photo's.iso
# Processing: G:\thecall\done\460\photos(2).iso -> 460_photos(2)
#   Path namespace: joliet_path
