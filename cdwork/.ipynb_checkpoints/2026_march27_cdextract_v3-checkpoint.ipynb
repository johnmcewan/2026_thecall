# %%
import os
import csv
import time
import pycdlib

# %%
# ---------- Configuration ----------

SOURCE_DIR = r"G:\thecall\done"
DEST_DIR   = r"e:\c_out"
CSV_PATH   = os.path.join(DEST_DIR, "inventory.csv")
ERROR_LOG  = os.path.join(DEST_DIR, "errors.log")

MAX_FILENAME_LEN = 200  # truncate filenames longer than this (before extension)

# %%
# ---------- Utilities ----------

def safe_path(path):
    """Prepend the Windows long-path prefix so paths > 260 chars work."""
    path = os.path.abspath(path)
    if not path.startswith("\\\\?\\"):
        return "\\\\?\\" + path
    return path


def clean_name(name):
    """Remove characters illegal on Windows and strip ISO version suffix (;1).

    Windows silently rejects directory/file names that end with a space or
    period even when using the long-path prefix, so we rstrip both.
    """
    if ";" in name:
        name = name[:name.rfind(";")]
    name = "".join(c if c not in '<>:"/\\|?*' else "_" for c in name)
    return name.rstrip(" .")


def truncate_name(name, max_len=MAX_FILENAME_LEN):
    """Truncate a filename while preserving its extension."""
    root, ext = os.path.splitext(name)
    if len(name) <= max_len:
        return name
    return root[: max_len - len(ext)] + ext


def detect_path_type(iso):
    """
    Choose the best path namespace for this ISO:
      'joliet_path' - disc has Joliet extensions (long, Unicode-friendly names)
      'iso_path'    - plain ISO 9660 (8.3 or slightly relaxed names)
    Rock Ridge is skipped; these discs don't have it.
    """
    if iso.joliet_vd is not None:
        return "joliet_path"
    return "iso_path"

# %%
# ---------- Date extraction (Final Refinement) ----------

def _parse_dir_record_date(dt):
    """Parse a DirectoryRecordDate (7-byte format)."""
    try:
        year = getattr(dt, "years_since_1900", None)
        day = getattr(dt, "day_of_month", None)
        if year is None or year == 0 or day is None:
            return ""
        return "{:04d}-{:02d}-{:02d} {:02d}:{:02d}:{:02d}".format(
            year + 1900, dt.month, day, dt.hour, dt.minute, dt.second,
        )
    except: return ""

def _parse_vd_date(dt):
    """Parse a VolumeDescriptorDate (17-byte ASCII format)."""
    if dt is None: return ""
    dstr = getattr(dt, "date_str", b"").decode("ascii", errors="ignore").strip("\x00 ")
    # Check if we have at least YYYYMMDD
    if len(dstr) >= 8 and dstr[:4].isdigit() and dstr[:4] != "0000":
        try:
            return "{}-{}-{} {}:{}:{}".format(
                dstr[0:4], dstr[4:6], dstr[6:8],
                dstr[8:10] or "00", dstr[10:12] or "00", dstr[12:14] or "00"
            )
        except: pass
    return ""

def get_all_dates(iso, iso_file_path, path_type):
    results = {"date_primary": "", "date_secondary": "", "date_volume": "", "date_source": ""}
    
    # 1. File Date (Primary Namespace)
    try:
        rec = iso.get_record(**{path_type: iso_file_path})
        results["date_primary"] = _parse_dir_record_date(rec.date)
    except: pass

    # 2. Volume Dates (The "Disc Date" - checking all 4 standard fields)
    pvd = iso.pvd
    v_cre = _parse_vd_date(getattr(pvd, "cre_date", None))
    v_mod = _parse_vd_date(getattr(pvd, "mod_date", None))
    v_eff = _parse_vd_date(getattr(pvd, "eff_date", None))
    
    # Use the first valid date found for the volume
    results["date_volume"] = v_mod or v_cre or v_eff
    
    # Label the source
    if results["date_primary"]:
        results["date_source"] = path_type
    elif results["date_volume"]:
        results["date_source"] = "volume_descriptor"
        
    return results

def _date_to_epoch(date_str):
    if not date_str: return None
    try: return time.mktime(time.strptime(date_str, "%Y-%m-%d %H:%M:%S"))
    except: return None

def stamp_file_date(out_path, dates):
    """Apply the best available date to the physical file on disk."""
    best = dates["date_primary"] or dates["date_volume"]
    epoch = _date_to_epoch(best)
    if epoch:
        try: os.utime(os.path.abspath(out_path), (epoch, epoch))
        except: pass

def log_error(message):
    with open(ERROR_LOG, "a", encoding="utf-8") as f:
        f.write(f"{time.strftime('%Y-%m-%d %H:%M:%S')} | {message}\n")

# %%
# ---------- Extraction Logic ----------

def extract_iso(iso_path, output_dir, writer):
    iso_name = os.path.basename(iso_path)
    iso = pycdlib.PyCdlib()
    try:
        iso.open(iso_path)
    except Exception as e:
        log_error(f"OPEN_FAIL | {iso_path} | {str(e)}")
        return

    path_type = detect_path_type(iso)
    print(f"  Path namespace: {path_type}")

    for dir_path, dirs, files in iso.walk(**{path_type: "/"}):
        for file in files:
            iso_file_path = dir_path.rstrip("/") + "/" + file
            
            try:
                clean_file = truncate_name(clean_name(file))
                rel_dir = dir_path.lstrip("/")
                if rel_dir:
                    rel_dir = os.path.join(*[clean_name(p) for p in rel_dir.split("/") if p])
                else:
                    rel_dir = "."

                out_dir = os.path.join(output_dir, rel_dir)
                out_path = os.path.join(out_dir, clean_file)

                os.makedirs(safe_path(out_dir), exist_ok=True)
                iso.get_file_from_iso(
                    local_path=safe_path(out_path),
                    **{path_type: iso_file_path},
                )

                dates = get_all_dates(iso, iso_file_path, path_type)
                stamp_file_date(out_path, dates)

                writer.writerow({
                    "iso_file":       iso_name,
                    "file_name":      clean_file,
                    "original_name":  file,
                    "folder":         rel_dir,
                    "full_path":      out_path,
                    "date_primary":   dates["date_primary"],
                    "date_secondary": dates["date_secondary"],
                    "date_volume":    dates["date_volume"],
                    "date_source":    dates["date_source"],
                    "path_type":      path_type,
                })
            except Exception as e:
                log_error(f"FILE_ERROR | {iso_name} | {iso_file_path} | {str(e)}")

    iso.close()

# %%
# ---------- Main Orchestrator ----------

def main():
    os.makedirs(DEST_DIR, exist_ok=True)
    
    fieldnames = [
        "iso_file", "file_name", "original_name",
        "folder", "full_path",
        "date_primary", "date_secondary", "date_volume",
        "date_source", "path_type",
    ]

    with open(CSV_PATH, "w", newline="", encoding="utf-8") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        for root, _, files in os.walk(SOURCE_DIR):
            for file in files:
                if file.lower().endswith(".iso"):
                    iso_path = os.path.join(root, file)
                    print(f"Processing: {iso_path}")
                    
                    iso_folder_name = os.path.splitext(file)[0]
                    out_folder = os.path.join(DEST_DIR, clean_name(iso_folder_name))
                    os.makedirs(safe_path(out_folder), exist_ok=True)

                    try:
                        extract_iso(iso_path, out_folder, writer)
                    except Exception as e:
                        log_error(f"FATAL | {iso_path} | {str(e)}")
                        print(f"  ERROR (skipped): {e}")

    print("Done.")

if __name__ == "__main__":
    main()
# Out:
# Processing: G:\thecall\done\12\Call 07-25-08-01.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\13\Call 08-08-08-15.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\14\Call 08-22-08-29.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\15\Call 09-05.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\16\09-13 Call.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\17\10-03 Call.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\1\05-02 Call.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\2\CALL 04-18-04-25.ISO
#   Path namespace: joliet_path
# Processing: G:\thecall\done\3\CALL 04-04-04-11.ISO
#   Path namespace: joliet_path
# Processing: G:\thecall\done\4\Call 05-09.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\5\Call 05-16.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\6\Call 05-23.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\7\Call 05-30.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\8\Call 06-06.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\9\Call 06-13-06-20.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\10\CALL 06-27-07-04.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\11\CALL 07-11-07-18.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\18\Call 09-20-09-26.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\19\Call 10-10.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\20\Call 10-17.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\21\Call 10-24.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\22\Call 10-31.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\23\Call 11-07.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\24\Call 11-14.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\25\Call 11-21.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\26\Call 11-28.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\27\Call 12-05.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\28\Call 12-12.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\29\Call 12-19.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\30\Call 12-26.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\33\33 Call 01-23-01.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\34\34 Call 02-06-02.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\31\Call 01-02.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\32\32 Call 01-09-0-.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\44\44 Call 07-02-07.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\45\45 Call 07-23-07.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\46\46 Call 08-06-08.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\47\47 Call 08-20-09.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\48\48 Call 09-10-09.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\35\35 Call 02-20-02.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\36\36 Call 03-05-03.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\37\37 Call 03-26-04.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\38\38 Call 04-09-04.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\39\39 Call 04-23-04.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\40\40 Call 05-07-05.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\41\41 Call 05-21-05.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\42\42 CALL 06-04-06.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\43\43 Call 06-18-06.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\49\49 Call 09-24-10.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\60\February 4-10.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\61\February 11-24.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\62\Feb25-March 03.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\63\March 04-17.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\64\March 18-24.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\50\50 Call 10-08-10.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\51\51 Call 10-22-10.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\52\52 Call 11-05-11.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\53\53 Call 11-19-11.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\54\54 Call 12-03-12.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\55\55 Call 12-17.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\56\56 Call 12-24.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\57\57 Call 12-31.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\58\Jan 7-20.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\59\Jan.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\77\July 29 - Aug 11.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\78\August 12-18.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\79\August 19-25..iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\80\Aug 26 - Sept 8.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\65\March 25-31.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\66\April 1-7.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\67\untitled.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\68\April 22- May 5.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\69\untitled(1).iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\70\May 13-19.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\71\May 20-26.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\72\untitled(2).iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\73\untitled(3).iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\74\untitled(4).iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\75\July 1-7 and 8-1.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\76\July 15-21 and 2.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\95\Feb 10.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\96\Feb 17-23.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\81\Sept 09-15.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\82\Sept 16-29.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\83\Sept 30 - Oct. 1.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\84\Oct. 14 - 27.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\85\Oct 28 - Nov. 10.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\86\Nov 11-17.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\87\Nov. 18-24.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\88\Nov. 25- Dec 8.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\89\untitled(5).iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\90\Dec 16-22.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\91\Dec 23 - Jan 05.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\92\Jan 6-19.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\93\Jan 20 - Feb 2.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\94\Feb 3-9.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\106\untitled(7).iso
# Processing: G:\thecall\done\107\May 26 - June 1.iso
# Processing: G:\thecall\done\97\untitled(6).iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\98\Mar 3-16.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\99\Mar 17-23.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\100\Mar 24-30.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\101\Mar 31 - April 6.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\102\April 7-20.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\103\April 21 - May 4.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\104\May 5.iso
# Processing: G:\thecall\done\105\May 12.iso
# Processing: G:\thecall\done\118\Aug 04.iso
# Processing: G:\thecall\done\119\Aug 11- 24.iso
# Processing: G:\thecall\done\120\Aug 25-31.iso
# Processing: G:\thecall\done\108\June 2-8.iso
# Processing: G:\thecall\done\109\untitled.iso
# Processing: G:\thecall\done\110\June 16-22.iso
# Processing: G:\thecall\done\111\June 23 - 29.iso
# Processing: G:\thecall\done\112\June 30 - July 6.iso
# Processing: G:\thecall\done\113\July 7 - 20.iso
# Processing: G:\thecall\done\114\July 21 - 27.iso
# Processing: G:\thecall\done\115\July 28.iso
# Processing: G:\thecall\done\116\Special Section.iso
# Processing: G:\thecall\done\117\Aug 04-10 #1.iso
# Processing: G:\thecall\done\129\Oct 27 - Nov 2.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\130\Nov 3.iso
# Processing: G:\thecall\done\121\Sept. 1-7.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\122\Sept 8-14.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\123\Sept 15-21.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\124\Sept 22-28.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\125\Sept 29 - Oct 5.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\126\Oct 6-12.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\127\Oct 13-19.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\128\Oct 20-26.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\138\Feb 12-Mar 01.iso
# Processing: G:\thecall\done\139\March 02-08.iso
# Processing: G:\thecall\done\140\March 9-22.iso
# Processing: G:\thecall\done\131\Nov 10-23.iso
# Processing: G:\thecall\done\132\Nov 24-Dec 7.iso
# Processing: G:\thecall\done\133\Dec 8-21.iso
# Processing: G:\thecall\done\134\Dec 22-Jan 4.iso
# Processing: G:\thecall\done\135\Jan 5-18.iso
# Processing: G:\thecall\done\136\Jan 19-Feb 01.iso
# Processing: G:\thecall\done\137\Feb 2-15.iso
# Processing: G:\thecall\done\148\June 1-7.iso
# Processing: G:\thecall\done\149\June 8-14.iso
# Processing: G:\thecall\done\150\June 15-21.iso
# Processing: G:\thecall\done\141\March 23-29.iso
# Processing: G:\thecall\done\142\March 30 - April 5.iso
# Processing: G:\thecall\done\143\April 6-19.iso
# Processing: G:\thecall\done\144\April 20-May 03.iso
# Processing: G:\thecall\done\145\May 4-10.iso
# Processing: G:\thecall\done\146\May 11-17.iso
# Processing: G:\thecall\done\147\May 18-24.iso
# Processing: G:\thecall\done\147A\May 25-31.iso
# Processing: G:\thecall\done\159\Sept 7-13.iso
# Processing: G:\thecall\done\160\Sept 7-13(1).iso
# Processing: G:\thecall\done\161\Sept 7-13 pt 3.iso
# Processing: G:\thecall\done\151\June 22- July 5.iso
# Processing: G:\thecall\done\152\July 5-19.iso
# Processing: G:\thecall\done\153\Untitled CD.iso
# Processing: G:\thecall\done\154\Aug 3-9.iso
# Processing: G:\thecall\done\155\Aug 10-16.iso
# Processing: G:\thecall\done\156\Aug 17-23.iso
# Processing: G:\thecall\done\157\Aug 24-30.iso
# Processing: G:\thecall\done\158\Aug 31 - Sept 06.iso
# Processing: G:\thecall\done\167\Oct 26-Nov 1.iso
# Processing: G:\thecall\done\168\Nov 2-8.iso
# Processing: G:\thecall\done\169\Nov 9-15.iso
# Processing: G:\thecall\done\170\Nov 9-15 pt 2.iso
# Processing: G:\thecall\done\162\Sept 14-20.iso
# Processing: G:\thecall\done\163\Sept 21-27.iso
# Processing: G:\thecall\done\164\Sept 28-Oct 4.iso
# Processing: G:\thecall\done\165\Oct 5-18.iso
# Processing: G:\thecall\done\166\Oct 19-25.iso
# Processing: G:\thecall\done\181\Jan 25-31.iso
# Processing: G:\thecall\done\182\Feb 01-07 pt 1.iso
# Processing: G:\thecall\done\183\Feb 1-7 pt 2.iso
# Processing: G:\thecall\done\171\Nov 16-22.iso
# Processing: G:\thecall\done\172\Untitled CD(1).iso
# Processing: G:\thecall\done\173\Nov 30- Dec 6.iso
# Processing: G:\thecall\done\174\Dec 7-13.iso
# Processing: G:\thecall\done\175\Dec 14-20.iso
# Processing: G:\thecall\done\176\Dec 21-27.iso
# Processing: G:\thecall\done\177\Dec 28 - Jan 3.iso
# Processing: G:\thecall\done\178\Jan 04-10.iso
# Processing: G:\thecall\done\179\Jan 11-17.iso
# Processing: G:\thecall\done\180\Jan 18-24.iso
# Processing: G:\thecall\done\187\Feb 15-21 pt 2.iso
# Processing: G:\thecall\done\184\Feb 8-14 pt 1.iso
# Processing: G:\thecall\done\185\Feb 8-14 pt 2.iso
# Processing: G:\thecall\done\186\Feb 15-21 pt 1.iso
# Processing: G:\thecall\done\299\February 13-19 pt2.iso
# Processing: G:\thecall\done\300\February 20-26 pt 1.iso
# Processing: G:\thecall\done\188 (broken)\Feb 22-28.iso
# Processing: G:\thecall\done\188 (broken)\Feb 22-28_v2.iso
# Processing: G:\thecall\done\189\Feb 22-28 pt 2.iso
# Processing: G:\thecall\done\190\Feb 29 - Mar 6.iso
# Processing: G:\thecall\done\191\March 07-13.iso
# Processing: G:\thecall\done\192\March 14-20 pt 1.iso
# Processing: G:\thecall\done\193\March 14-20 pt2.iso
# Processing: G:\thecall\done\194\March 21-27 pt 1.iso
# Processing: G:\thecall\done\195\March 21-27 pt 2.iso
# Processing: G:\thecall\done\196\March 28 - April 3 pt 1.iso
# Processing: G:\thecall\done\197\March 28- April 3 pt 2.iso
# Processing: G:\thecall\done\198\Untitled CD.iso
# Processing: G:\thecall\done\199\April 11-17.iso
# Processing: G:\thecall\done\200\April 11-17(1).iso
# Processing: G:\thecall\done\201\April 18-24.iso
# Processing: G:\thecall\done\202\April 18-24(1).iso
# Processing: G:\thecall\done\203\April 25-May 01.iso
# Processing: G:\thecall\done\204\April 25-May 01(1).iso
# Processing: G:\thecall\done\205\May 02-08 pt1.iso
# Processing: G:\thecall\done\206\May 02-08 pt2.iso
# Processing: G:\thecall\done\207\May 09-15 pt1.iso
# Processing: G:\thecall\done\208\May 09-15 pt2.iso
# Processing: G:\thecall\done\209\May09-15 pt3.iso
# Processing: G:\thecall\done\210\May 16-22 pt1.iso
# Processing: G:\thecall\done\211\May 16-22 pt2.iso
# Processing: G:\thecall\done\212\May 23-29 pt1.iso
# Processing: G:\thecall\done\213\May23-29 pt2.iso
# Processing: G:\thecall\done\214\May 30 - June 05 pt1.iso
# Processing: G:\thecall\done\215\May 30-June 05 pt2.iso
# Processing: G:\thecall\done\216\June 6-12 pt 1.iso
# Processing: G:\thecall\done\217\June 6-12 pt2.iso
# Processing: G:\thecall\done\218\June 13-19 pt1.iso
# Processing: G:\thecall\done\219\June 13-19 pt2.iso
# Processing: G:\thecall\done\220\June 20-26 pt1.iso
# Processing: G:\thecall\done\221\June 20-26 pt2.iso
# Processing: G:\thecall\done\222\June 27- July 03 pt1.iso
# Processing: G:\thecall\done\223\June 27.iso
# Processing: G:\thecall\done\224\July 04-10 pt 1.iso
# Processing: G:\thecall\done\225\July 04-10 pt2.iso
# Processing: G:\thecall\done\226\July 11-17 pt1.iso
# Processing: G:\thecall\done\227\July 11-17 pt2.iso
# Processing: G:\thecall\done\228\July 18-24 pt 1.iso
# Processing: G:\thecall\done\229\July 18-24 pt 2.iso
# Processing: G:\thecall\done\230\July 25-31 pt1.iso
# Processing: G:\thecall\done\231\July 25-31 pt2.iso
# Processing: G:\thecall\done\232\August 1-7 pt1.iso
# Processing: G:\thecall\done\233\August 1-7 pt2.iso
# Processing: G:\thecall\done\234\August 08-14.iso
# Processing: G:\thecall\done\235\August 08-14 pt 2.iso
# Processing: G:\thecall\done\236\August 15-21.iso
# Processing: G:\thecall\done\237\August 15-21 pt2.iso
# Processing: G:\thecall\done\238\August 22-28 pt1.iso
# Processing: G:\thecall\done\239\August 22-28 pt2.iso
# Processing: G:\thecall\done\240\August 29-September 4 pt1.iso
# Processing: G:\thecall\done\241\August 29 - Spetember 4 pt2.iso
# Processing: G:\thecall\done\242\Sept 05-11 pt1.iso
# Processing: G:\thecall\done\243\Sept 05-11 pt2.iso
# Processing: G:\thecall\done\244\September 12-18 pt1.iso
# Processing: G:\thecall\done\245\September 12-18 pt2.iso
# Processing: G:\thecall\done\246\September 19-25 pt1.iso
# Processing: G:\thecall\done\247\September 19-25 pt 2.iso
# Processing: G:\thecall\done\248\September 26 - October 02 Pt 1.iso
# Processing: G:\thecall\done\249\September 26 - October 02.iso
# Processing: G:\thecall\done\250\October 03-09.iso
# Processing: G:\thecall\done\251\October 03-09 pt2.iso
# Processing: G:\thecall\done\252\October 10-16 pt1.iso
# Processing: G:\thecall\done\253\October 10-16 pt2.iso
# Processing: G:\thecall\done\254\October 17-23 pt1.iso
# Processing: G:\thecall\done\255\October 17-23 p2.iso
# Processing: G:\thecall\done\256\October 24-30 pt.iso
# Processing: G:\thecall\done\257\October 24-30 pt2.iso
# Processing: G:\thecall\done\258\October 24-30 pt3.iso
# Processing: G:\thecall\done\259\October 31-Novemeber 6.iso
# Processing: G:\thecall\done\260\October 31 November 6 Pt 2.iso
# Processing: G:\thecall\done\261\October 31 - November 6 pt3.iso
# Processing: G:\thecall\done\262\November 07-13 pt 1.iso
# Processing: G:\thecall\done\263\November 07-13 pt 2.iso
# Processing: G:\thecall\done\264\Untitled CD(1).iso
# Processing: G:\thecall\done\265\November 07-13 pt 4.iso
# Processing: G:\thecall\done\266\November 07-13 pt 5.iso
# Processing: G:\thecall\done\267\November 07-13 pt 6.iso
# Processing: G:\thecall\done\268\November 07-13 pt 7.iso
# Processing: G:\thecall\done\269\November 14-20 pt1.iso
# Processing: G:\thecall\done\270\November 14-20 pt2.iso
# Processing: G:\thecall\done\271\November 14-20 pt3.iso
# Processing: G:\thecall\done\272\November 21-27 pt 1.iso
# Processing: G:\thecall\done\273\November 21-27 pt 2.iso
# Processing: G:\thecall\done\274\November 28-Decmber 04 Pt 1.iso
# Processing: G:\thecall\done\275\November 28-Decmber 04 PT 2.iso
# Processing: G:\thecall\done\276\December 05-11 pt1.iso
# Processing: G:\thecall\done\277\December 05-11 pt 2.iso
# Processing: G:\thecall\done\278\December 12-18 pt1.iso
# Processing: G:\thecall\done\279\December 12-18 pt2.iso
# Processing: G:\thecall\done\280\December 19-25 pt 1.iso
# Processing: G:\thecall\done\281\December 19-25 pt2.iso
# Processing: G:\thecall\done\282\Untitled CD(2).iso
# Processing: G:\thecall\done\283\December 26- January 01.iso
# Processing: G:\thecall\done\284\December 26- January 1.iso
# Processing: G:\thecall\done\285\January 02-08 pt1.iso
# Processing: G:\thecall\done\286\January 02-08 pt2.iso
# Processing: G:\thecall\done\287\January 09-15 pt1.iso
# Processing: G:\thecall\done\288\January 09-15 pt2.iso
# Processing: G:\thecall\done\289\January 16-22 pt1.iso
# Processing: G:\thecall\done\290\January 16-22 pt2.iso
# Processing: G:\thecall\done\291\January 23-29.iso
# Processing: G:\thecall\done\292\January 23-29 pt2.iso
# Processing: G:\thecall\done\293\January 23-29 pt3.iso
# Processing: G:\thecall\done\294\January 30-Febuaury 05.iso
# Processing: G:\thecall\done\295\January 05- Febuaury 05 pt2.iso
# Processing: G:\thecall\done\296\Febuaury 06-12 Pt1.iso
# Processing: G:\thecall\done\297\Febuaury 06-12 pt2.iso
# Processing: G:\thecall\done\298\February 13-19 pt1.iso
# Processing: G:\thecall\done\439\Sept 05 - Oct 02.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\440\Oct 3 - Nov 06.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\301\Februrary 20-26 pt2.iso
# Processing: G:\thecall\done\302\February 27 - March 03 PT 1.iso
# Processing: G:\thecall\done\303\February 27 - March 03 Pt2.iso
# Processing: G:\thecall\done\304\March 06-12 pt1.iso
# Processing: G:\thecall\done\305\March 06-12 pt2.iso
# Processing: G:\thecall\done\306\March 13-19 Pt1.iso
# Processing: G:\thecall\done\307\March 13-19 Pt2.iso
# Processing: G:\thecall\done\308\March 20-26 Pt1.iso
# Processing: G:\thecall\done\309\March 20-26 Pt2.iso
# Processing: G:\thecall\done\310\March 20-26 Pt 3.iso
# Processing: G:\thecall\done\311\March 27- April 02 Pt1.iso
# Processing: G:\thecall\done\312\March 27-April 02 PT2.iso
# Processing: G:\thecall\done\313\April 03-09 pt1.iso
# Processing: G:\thecall\done\314\April 03-09 pt2.iso
# Processing: G:\thecall\done\315\April 10-16 pt1.iso
# Processing: G:\thecall\done\316\April 10-16 Pt2.iso
# Processing: G:\thecall\done\317\April 17-23 pt1.iso
# Processing: G:\thecall\done\318\April 17-23 pt2.iso
# Processing: G:\thecall\done\319\April 24-30 pt1.iso
# Processing: G:\thecall\done\320\April 24-30 Pt2.iso
# Processing: G:\thecall\done\321\April 24-30 pt3.iso
# Processing: G:\thecall\done\322\May 01-07 pt1.iso
# Processing: G:\thecall\done\323\May 01-07 pt2.iso
# Processing: G:\thecall\done\324\May 08-14 PT1.iso
# Processing: G:\thecall\done\325\May 08-14 Pt2.iso
# Processing: G:\thecall\done\326\May 8-14 pt 3.iso
# Processing: G:\thecall\done\327\May 8-14 Pt4.iso
# Processing: G:\thecall\done\328\May 15-21 Complete.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\329\May 22-28.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\330\May 29 - June 04 complete.iso
#   Path namespace: joliet_path
# Processing: G:\thecall\done\331\_June 05-11 _ 12-18 Complete.iso
#   Path namespace: joliet_path
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 36
#      33     print("Done.")
#      35 if __name__ == "__main__":
# ---> 36     main()
#
# Cell In[6], line 28, in main()
#      25 os.makedirs(safe_path(out_folder), exist_ok=True)
#      27 try:
# ---> 28     extract_iso(iso_path, out_folder, writer)
#      29 except Exception as e:
#      30     log_error(f"FATAL | {iso_path} | {str(e)}")
#
# Cell In[5], line 31, in extract_iso(iso_path, output_dir, writer)
#      28 out_path = os.path.join(out_dir, clean_file)
#      30 os.makedirs(safe_path(out_dir), exist_ok=True)
# ---> 31 iso.get_file_from_iso(
#      32     local_path=safe_path(out_path),
#      33     **{path_type: iso_file_path},
#      34 )
#      36 dates = get_all_dates(iso, iso_file_path, path_type)
#      37 stamp_file_date(out_path, dates)
#
# File ~\miniforge3\envs\thecall\Lib\site-packages\pycdlib\pycdlib.py:4224, in PyCdlib.get_file_from_iso(self, local_path, **kwargs)
#    4222     self._udf_get_file_from_iso_fp(fp, blocksize, udf_path)
#    4223 else:
# -> 4224     self._get_file_from_iso_fp(fp, blocksize, iso_path, rr_path,
#    4225                                joliet_path)
#
# File ~\miniforge3\envs\thecall\Lib\site-packages\pycdlib\pycdlib.py:2592, in PyCdlib._get_file_from_iso_fp(self, outfp, blocksize, iso_path, rr_path, joliet_path)
#    2590                 utils.copy_data(data_len, blocksize, data_fp, outfp)
#    2591     else:
# -> 2592         utils.copy_data(data_len, blocksize, data_fp, outfp)
#    2594 if found_record.data_continuation is not None:
#    2595     found_record = found_record.data_continuation
#
# File ~\miniforge3\envs\thecall\Lib\site-packages\pycdlib\utils.py:109, in copy_data(data_length, blocksize, infp, outfp)
#     107 if left < readsize:
#     108     readsize = left
# --> 109 data = infp.read(readsize)
#     110 # We have seen ISOs in the wild (Tribes Vengeance 1of4.iso) that
#     111 # lie about the size of their files, causing reads to fail (since
#     112 # we hit EOF before the supposed end of the file).  If we got less data
#     113 # than we asked for, abort the loop silently.
#     114 data_len = len(data)
#
# KeyboardInterrupt:

# %%
if __name__ == "__main__":
    main()
